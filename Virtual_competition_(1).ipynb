# %% [markdown]
# <a href="https://colab.research.google.com/github/aneesaameerali/ict/blob/main/Virtual_competition_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
import pandas as pd
import numpy as np


data = {
    'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
    'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
    'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']
}


labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']


df = pd.DataFrame(data, index=labels)


print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
import pandas as pd

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=labels)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
df = pd.DataFrame(data, index=labels)

print(df.head(3))
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
df = pd.DataFrame(data, index=labels)

print(df[['animal', 'age']])
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
f = pd.DataFrame(data, index=labels)

print(df.iloc[[3,4,8]][['animal', 'age']])
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
df = pd.DataFrame(data, index=labels)

print(df[df['visits'] > 3])
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
df = pd.DataFrame(data, index=labels)

print(df[df['age'].isnull()])
# Out:
#   animal  age  visits priority
# d    dog  NaN       3       no
# h    cat  NaN       1       no

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
print(df[(df['animal'] == 'cat') & (df['age'] < 3)])
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3      yes

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
print(df[df['age'].between(2, 4)])
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3      yes
# j    dog  3.0       1      yes

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
df.loc['f', 'age'] = 1.5
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3       no
# e    dog  5.0       2      yes
# f    cat  1.5       3      yes
# g  snake  4.5       1       no
# h    cat  NaN       1       no
# i    dog  7.0       2      yes
# j    dog  3.0       1      yes

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
print(df['visits'].sum())
# Out:
# 19

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
print(df.groupby('animal')['age'].mean())
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
df = pd.DataFrame(data, index=labels)

df.loc['k'] = ['lizard', 2.0, 1, 'no']

df = df.drop('k')
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3       no
# e    dog  5.0       2      yes
# f    cat  2.0       3      yes
# g  snake  4.5       1       no
# h    cat  NaN       1       no
# i    dog  7.0       2      yes
# j    dog  3.0       1      yes

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
print(df['animal'].value_counts())
# Out:
# animal
# cat      4
# dog      4
# snake    2
# Name: count, dtype: int64

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
df = df.sort_values(by=['age', 'visits'], ascending=[False, True])

print(df)
# Out:
#   animal  age  visits priority
# i    dog  7.0       2      yes
# e    dog  5.0       2      yes
# g  snake  4.5       1       no
# j    dog  3.0       1      yes
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  2.0       3      yes
# c  snake  0.5       2       no
# h    cat  NaN       1       no
# d    dog  NaN       3       no

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
df['priority'] = df['priority'].map({'yes': True, 'no': False})

print(df)
# Out:
#   animal  age  visits  priority
# i    dog  7.0       2      True
# e    dog  5.0       2      True
# g  snake  4.5       1     False
# j    dog  3.0       1      True
# b    cat  3.0       3      True
# a    cat  2.5       1      True
# f    cat  2.0       3      True
# c  snake  0.5       2     False
# h    cat  NaN       1     False
# d    dog  NaN       3     False

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
df['animal'] = df['animal'].replace('snake', 'python')

print(df)
# Out:
#    animal  age  visits  priority
# i     dog  7.0       2      True
# e     dog  5.0       2      True
# g  python  4.5       1     False
# j     dog  3.0       1      True
# b     cat  3.0       3      True
# a     cat  2.5       1      True
# f     cat  2.0       3      True
# c  python  0.5       2     False
# h     cat  NaN       1     False
# d     dog  NaN       3     False

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
import pandas as pd
import pandas as pd
import numpy as np

flights= pd.read_csv('/content/ny-flights.csv')
print(flights)
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %%
# promot: which airline ID is present maximum times in the dataset
flights['airline_id'].value_counts(). idxmax()
# Out:
# 20409

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
#promot: draw a plot between dep_delay and arr_delay

flights.plot(x='dep_delay', y='arr_delay', kind='scatter')
# Out:
# <Axes: xlabel='dep_delay', ylabel='arr_delay'>

# %% [markdown]
# Diabetes_model

# %%
import pandas as pd
import numpy as np

Diabetes_df = pd.read_csv('/content/diabetes_model.csv')
print(Diabetes_df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %%
for feature in numerical_features:
    plt.figure(figsize=(10, 5))


    plt.subplot(1, 2, 1)
    sns.histplot(diabetes_df[feature], kde=True)
    plt.title(f'Distribution of {feature}')

    plt.subplot(1, 2, 2)
    sns.boxplot(y=diabetes_df[feature])
    plt.title(f'Box plot of {feature}')

    plt.tight_layout()
    plt.show()

plt.figure(figsize=(6, 4))
sns.countplot(x=diabetes_df['Outcome'])
plt.title('Distribution of Outcome')
plt.show()

# %%
sns.scatterplot(x=diabetes_df['Glucose'], y=diabetes_df['BMI'])
plt.title('Glucose vs BMI')
plt.show()

sns.scatterplot(x=diabetes_df['Age'], y=diabetes_df['BloodPressure'])
plt.title('Age vs BloodPressure')
plt.show()


plt.figure(figsize=(10, 8))
sns.heatmap(diabetes_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(diabetes_df['Glucose'], diabetes_df['BMI'], diabetes_df['Age'], c=diabetes_df['Outcome'])
ax.set_xlabel('Glucose')
ax.set_ylabel('BMI')
ax.set_zlabel('Age')
ax.set_title('3D Scatter Plot of Glucose, BMI, and Age')
plt.show()

# %%
sns.pairplot(diabetes_df[['Glucose', 'BMI', 'Age', 'Outcome']], hue='Outcome')
plt.show()
